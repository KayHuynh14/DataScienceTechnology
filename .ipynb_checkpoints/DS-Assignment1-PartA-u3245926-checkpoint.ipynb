# %% [markdown]
# # DATA SCIENCE TECHNOLOGY AND SYSTEM
# # Assignment – 1
# ### Predictive Modelling of Eating-Out problem
# Student name: Kay Huynh
# Student ID: u3245926

# %% [markdown]
# ### Part A –Importing and Understanding Data

# %%
# Import packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read data
data= pd.read_csv('data\zomato_df_final_data.csv')

# %% [markdown]
# ### 1/ Provide plots/graphs to support:
# #### How many unique cuisines are served by Sydney restaurants?

# %%
# Cuisine column processing 
data['cuisine'] = data['cuisine'].str.split(', ')
restaurant_df = data.explode("cuisine").reset_index(drop=True)
restaurant_df['cuisine'] = restaurant_df['cuisine'].astype(str)
restaurant_df['cuisine'] = restaurant_df['cuisine'].str.replace('[', '')
restaurant_df['cuisine'] = restaurant_df['cuisine'].str.replace("'", '')
restaurant_df['cuisine'] = restaurant_df['cuisine'].str.replace("]", '')

# %%
# type column processing 
restaurant_df['type'] = restaurant_df ['type'].str.split(', ')
restaurant_df = restaurant_df.explode("type").reset_index(drop=True)
restaurant_df['type'] = restaurant_df['type'].astype(str)
restaurant_df['type'] = restaurant_df['type'].str.replace('[', '')
restaurant_df['type'] = restaurant_df['type'].str.replace("'", '')
restaurant_df['type'] = restaurant_df['type'].str.replace("]", '')

# %%
# Visualize the cuisine bar chart
# Create UniqueCuisine data
UniqueCuisine = restaurant_df.groupby(['cuisine']).size().reset_index().rename(columns={0: "Cuisine_Count"})

# Sort UniqueCuisine DataFrame by 'Cuisine_Count' in descending order
UniqueCuisine = UniqueCuisine.sort_values(by='Cuisine_Count', ascending=False)
cuisine_counts = UniqueCuisine.groupby('cuisine')['Cuisine_Count'].sum().reset_index()

# Summarize all cuisine occur less than 100 to others
# Identify cuisines with counts less than 100
under100_cuisines = cuisine_counts[cuisine_counts['Cuisine_Count'] < 100]

# Create "Others" category and aggregate counts
other_category = {
    'cuisine': 'Others',
    'Cuisine_Count': under100_cuisines['Cuisine_Count'].sum()
}
# Remove rows under 100 times occur
cuisine_counts = cuisine_counts[~cuisine_counts['cuisine'].isin(under100_cuisines['cuisine'])]

# Append the "Others" category
cuisine_counts = pd.concat([cuisine_counts, pd.DataFrame([other_category])], ignore_index=True)

# Sort the DataFrame by cuisine count
cuisine_counts = cuisine_counts.sort_values(by='Cuisine_Count', ascending=False)

# Create the bar plot with seaborn
plt.figure(figsize=(30, 10))
sns.barplot(x='cuisine', y='Cuisine_Count', data=cuisine_counts)
plt.title('Unique cuisines are served by Sydney restaurants', size=30)
plt.xlabel('Cuisines', size=30)
plt.ylabel('Restaurants sell', size=30)
plt.yticks(size = 20)
plt.xticks(rotation=90, size = 20) 
plt.show()

# %% [markdown]
# #### Which suburbs (top-3) have the highest number of restaurants?

# %%
subzone = data['subzone'].value_counts().head(3).to_frame()
subzone['subzone names'] = subzone.index

X = subzone["subzone names"].tolist()
Y = subzone['count'].tolist()

# Create a bar chart
plt.bar(X, Y, color ="c")

# Function to add value labels
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]//2, y[i], ha = 'center')
    
# Calling the function to add value labels
addlabels(X, Y)
# Add labels and a title
plt.xlabel('Suburbs')
plt.ylabel('Number of restaurants')
plt.title('Suburbs (top-3) have the highest number of restaurants')

# Show the chart
plt.show()

# %% [markdown]
# #### “Restaurants with ‘excellent’ rating are mostly very expensive while those with ‘Poor’ rating are rarely expensive”. Do you agree on this statement or not? Please support your answer by numbers and visuals. (hint: use stacked bar chart or histogram to relate ‘cost’ to 'rating_text')

# %%
# Create a FacetGrid of histograms
# Create a color palette for the plot
colors = sns.color_palette("Set2")

g = sns.displot(
    data=restaurant_df, x='cost', col='rating_text',
    binwidth=30, height=5, facet_kws=dict(margin_titles=True), palette=colors
)

# Set axis labels for the FacetGrid
g.set_axis_labels('Cost for Two', 'Frequency')


# Set titles for each facet
g.set_titles(col_template='{col_name} Rating', size=16)

# Customize the appearance of the plot
sns.set_style("whitegrid")  # Set the background style
plt.subplots_adjust(top=0.85)  # Adjust the top margin for titles
plt.suptitle('Cost Distribution by Rating', fontsize=20)  # Main title

# Show the plot
plt.show()
# Out:
# C:\Users\TDC\AppData\Local\Temp\ipykernel_1588\414886535.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   g = sns.displot(
# C:\Users\TDC\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ###### Answer question:
# Based on the histogram by rating, I disagree with the statement, because the cost for two distribution of Excellent and poor rating are nearly the same, under 200 dollars. There are only few restaurants with exellent rating have cost for 2 over 300 dollars.

# %% [markdown]
# ### 2/ Perform exploratory analysis for the variables of the data. This can be done by producing histograms and distribution plots and descriptive insights about these variables. This can be performed at least for the following variables.
# o Cost
# o Rating
# o Type

# %% [markdown]
# ### Exploratory analysis for Cost

# %%
# Distribuition of cost for two
costForTwo = restaurant_df['cost'].tolist()

sns.histplot(costForTwo, bins=20)

# Add labels and a title
plt.xlabel('Cost')
plt.ylabel('Frequency')
plt.title('Distribuition of cost for two')
# Customize the appearance of the plot
sns.set_style("whitegrid")  # Set the background style
plt.subplots_adjust(top=0.85)  # Adjust the top margin for titles

# Show the plot
plt.show()

# %%
# Top resutaurants by rating
# Group the data by 'subzone' and calculate the average of 'cost' for each location
location_cost = restaurant_df.groupby('subzone')['cost'].mean().reset_index().sort_values(by='cost', ascending=False).head(10)
location_cost
# Out:
#                             subzone        cost
# 486   The Bathers' Pavilion, Mosman  212.000000
# 443  Sofitel Sydney Darling Harbour  200.000000
# 126        D'Albora Marinas, Mosman  200.000000
# 366           Park Hyatt, The Rocks  197.500000
# 387                    Primus Hotel  150.000000
# 262                  Little Hartley  150.000000
# 390   Pullman Sydney Hyde Park, CBD  147.500000
# 501                The Langham, CBD  140.000000
# 130   Darling Park, Darling Harbour  138.888889
# 438       Sheraton on the Park, CBD  134.000000

# %%
# Create a bar chart to display top suburbs
plt.figure(figsize=(10, 6))
plt.bar(location_cost['subzone'], location_cost['cost'], color='teal')
plt.xlabel('Suburbs')
plt.ylabel('Cost')
plt.title('Top 10 suburbs have highest cost for two')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

# Display the number of votes on top of each bar
for index, row in location_cost.iterrows():
    plt.text(row['subzone'], row['cost'], int(row['cost']), ha='center', va='bottom')
# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Exploratory analysis for Rating

# %%
# Create a histogram for distribuition of rating
rating = restaurant_df['rating_number'].tolist()

sns.histplot(rating, bins=20, color = "magenta")

# Add labels and a title
plt.xlabel('Ratings',size=10)
plt.ylabel('Frequency',size=10)
plt.title('Distribuition of rating',size=20)
# Customize the appearance of the plot
sns.set_style("whitegrid")  # Set the background style
plt.subplots_adjust(top=0.85)  # Adjust the top margin for titles
# Show the plot
plt.show()

# %%
# Top resutaurants by rating
# Group the data by 'title' and calculate the average of 'rating number' for each location
title_rating = restaurant_df.groupby('title')['rating_number'].mean().reset_index().sort_values(by='rating_number', ascending=False).head(20)
title_rating

# Create a bar chart to display top restaurants
plt.figure(figsize=(10, 6))
plt.bar(title_rating['title'], title_rating['rating_number'], color='skyblue')
plt.xlabel('Restaurant name')
plt.ylabel('Rating')
plt.title('Top 20 highest rating restaurants')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Relational plot between cost and rating
sns.relplot(x ="cost", y ="rating_number", data = restaurant_df)
# Out:
# C:\Users\TDC\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Exploratory analysis for Type

# %%
# Distribuition of type
typeOfRest = restaurant_df['type'].tolist()

sns.histplot(typeOfRest, bins=20)

# Add labels and a title
plt.xlabel('Type')
plt.xticks(rotation =90)
plt.ylabel('Frequency')
plt.title('Distribuition of type')

# Show the plot
plt.show()

# %% [markdown]
# ### Exploratory analysis for Vote

# %%
# Group the data by 'Location' and calculate the sum of 'Votes' for each location
location_votes = restaurant_df.groupby('subzone')['votes'].sum().reset_index().sort_values(by='votes', ascending=False).head(10)

# %%
# Create a bar chart to display the number of votes by location
plt.figure(figsize=(10, 6))
plt.bar(location_votes['subzone'], location_votes['votes'], color='olive')
plt.xlabel('Location')
plt.ylabel('Number of Votes')
plt.title('Number of Votes by Location')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

# Display the number of votes on top of each bar
for index, row in location_votes.iterrows():
    plt.text(row['subzone'], row['votes'], str(row['votes']), ha='center', va='bottom')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3- Produce Cuisine Density Map: Using the restaurant geographic information and the provided “sydney.geojson” file, write a python function to show a cuisine density map where each suburb is colour-coded by the number of restaurants that serve a particular cuisine. This function can be called as:
# “show_cuisine_densitymap(cuisine='Indian')”.
# (Hint: use the spatial join in geopandas)

# %%
#pip install geopandas and read map file
import geopandas as gpd
sydney = gpd.read_file("data/sydney.geojson")

print(sydney.head())
# Out:
#   SSC_CODE          SSC_NAME CONF_VALUE      SQKM  \
# 0    10001        Abbotsbury  Very good  4.984673
# 1    10002  Abbotsford (NSW)  Very good  1.017855
# 2    10010    Acacia Gardens  Very good  0.946630
# 3    10016             Airds  Very good  2.380773
# 4    10022        Alexandria  Very good  3.503330
#
#                                             geometry
# 0  POLYGON ((150.85118 -33.87069, 150.85104 -33.8...
# 1  POLYGON ((151.12593 -33.84578, 151.12678 -33.8...
# 2  POLYGON ((150.90781 -33.73547, 150.90799 -33.7...
# 3  POLYGON ((150.84000 -34.07817, 150.84077 -34.0...
# 4  POLYGON ((151.18603 -33.91660, 151.18562 -33.9...

# %%
# Show boundary map
sydney.plot(figsize=(10, 10), edgecolor='blue', facecolor='white')
# Out:
# <Axes: >

# %%
# Join data and map
geometry = gpd.points_from_xy(restaurant_df["lng"], restaurant_df["lat"])
restaurant_df = gpd.GeoDataFrame(restaurant_df, geometry=geometry)

combined_gdf = gpd.sjoin(sydney, restaurant_df, how="left", op="intersects")

combined_gdf.plot(figsize=(10, 10), edgecolor='blue', facecolor='white')
# Out:
# C:\Users\TDC\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# C:\Users\TDC\AppData\Local\Temp\ipykernel_1588\3058984891.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: None
#
#   combined_gdf = gpd.sjoin(sydney, restaurant_df, how="left", op="intersects")
# <Axes: >

# %%
# Show cuisine map function
def show_cuisine_densitymap(cuisine):

    map_gdf = combined_gdf
    
    # Read suburb boundaries from a GeoJSON file
    desired_cuisine = cuisine

    # Filter restaurants serving the specified cuisine
    cuisine_restaurants = map_gdf[map_gdf['cuisine'] == desired_cuisine]
    
    # Perform a spatial join to count the number of cuisine-specific restaurants in each suburb
    suburb_cuisine_count = cuisine_restaurants.groupby('SSC_NAME')['title'].count().reset_index(name='RestaurantCount')
    
    # Merge the counts with the suburb GeoDataFrame
    map_gdf = map_gdf.merge(suburb_cuisine_count, on='SSC_NAME', how='left')
    map_gdf['RestaurantCount'] = map_gdf['RestaurantCount'].fillna(0)

    # Plot the cuisine density map
    fig, ax = plt.subplots(1, 1, figsize=(12, 8))
    map_gdf.plot(column='RestaurantCount', cmap='YlGn', linewidth=1, ax=ax, edgecolor='0.6', legend=True)
    ax.set_title(f'{cuisine}')
    plt.axis('off')
    plt.show()

# %%
# Example usage:
show_cuisine_densitymap(cuisine='Indian')

# %%
# Example usage:
show_cuisine_densitymap(cuisine='Chinese')

# %% [markdown]
# #### Bonus:
# I think the non-interactive plotting is limiting when applied to visualizing real-time data trends. It means that we cannot interact with the plot to investigate specific data points or time intervals when the real-time data trends change by static plots. With static plots, we just display the snapshot of the data at a specific point in time and also cannot explore the data dynamically.
#
# In terms of interactive libraries such as Bokeh, Plotly and so on, they could support to creation of real-time updates of the plot. In other words, the data automatically updates to present the most recent data points. Furthermore, interactive libraries also provide the widget and controls function to modify the users’ view of the dataset. By building the dashboard from libraries, users could combine and display multiple plots and visualizations. It means that allows users to interact with various visual elements on a single web page.
